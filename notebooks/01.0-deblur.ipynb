# %% [markdown]
# # Deblur
# > Deblur uses sequence error profiles to associate erroneous sequence reads with the true biological sequence from which they are derived, resulting in high quality sequence variant data. This is applied in two steps. First, an initial quality filtering process based on quality scores is applied. This method is an implementation of the quality filtering approach described by Bokulich et al. (2013).
#
# > Next, the Deblur workflow is applied using the qiime deblur denoise-16S method. This method requires one parameter that is used in quality filtering, --p-trim-length n which truncates the sequences at position n. In general, the Deblur developers recommend setting this value to a length where the median quality score begins to drop too low. On these data, the quality plots (prior to quality filtering) suggest a reasonable choice is in the 115 to 130 sequence position range. This is a subjective assessment. One situation where you might deviate from that recommendation is when performing a meta-analysis across multiple sequencing runs. In this type of meta-analysis, it is critical that the read lengths be the same for all of the sequencing runs being compared to avoid introducing a study-specific bias. Since we already using a trim length of 120 for qiime dada2 denoise-single, and since 120 is reasonable given the quality plots, we’ll pass --p-trim-length 120. This next command may take up to 10 minutes to run.

# %%
import os
import pandas as pd

def qiime_manifest(path, out):
    try:
        os.mkdir(out)
    except FileExistsError:
        pass
    else:
        try:
            os.mkdir(out.rsplit('/', 1)[0])
        except FileNotFoundError:
            print('check outdir')   

    manifest = sorted([i for i in os.listdir(os.path.abspath(path)) if i.endswith('.fastq.gz')])
    ctr = 0
    df = pd.DataFrame(columns=['sample-id','forward-absolute-filepath','reverse-absolute-filepath'])

    for i in range(int(len(manifest)/2)):
        forward = manifest[ctr]
        reverse = manifest[ctr+1]
        sampleid = (manifest[ctr].rsplit('.', 3)[0])
        #print(sampleid)
        if 'unknown' in sampleid:
            print('dropped:', sampleid)
        else:
            df.loc[i] = [sampleid.replace('_', '-'), os.path.abspath(os.path.join(path, forward)), os.path.abspath(os.path.join(path, reverse))]
        ctr = ctr+2
    df.to_csv(out+'/manifest.txt', sep='\t', index=False)
    return

for i in range(3):
    path = '../data/preprocessing/Psoil-'+str(i+1)+'/clean/'
    out = '../data/qiime2/Psoil-'+str(i+1)
    qiime_manifest(path, out)
# Out:
# dropped: unknown
# dropped: round2-unknown
# dropped: unknown
# dropped: unknown

# %%
os.path.abspath('../data/qiime2/Psoil-1/manifest.txt')
# Out:
# '/home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn16s/data/qiime2/Psoil-1/manifest.txt'

# %%
df1 = pd.read_csv('../data/qiime2/Psoil-1/manifest.txt', sep='\t')
df2 = pd.read_csv('../data/qiime2/Psoil-2/manifest.txt', sep='\t')
df3 = pd.read_csv('../data/qiime2/Psoil-3/manifest.txt', sep='\t')
frames = [df1, df2, df3]
df_all = pd.concat(frames)
df_all = df_all[df_all['sample-id'].isin([i for i in df_all['sample-id'] if i.startswith(('P5', 'P8', 'P9'))])]
df_all.to_csv('../data/qiime2/manifest-selection.txt', sep='\t', index=False)
df_all
# Out:
#   sample-id                          forward-absolute-filepath  \
# 0   P5-rep1  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 1   P5-rep2  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 2   P5-rep3  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 3   P5-rep4  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 4   P5-rep5  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 5   P8-rep1  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 6   P8-rep2  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 7   P8-rep3  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 8   P8-rep4  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 9   P8-rep5  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 1   P9-rep1  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 2   P9-rep2  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 3   P9-rep3  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 4   P9-rep4  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 5   P9-rep5  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
#
#                            reverse-absolute-filepath
# 0  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 1  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 2  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 3  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 4  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 5  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 6  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 7  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 8  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 9  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 1  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 2  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 3  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 4  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...
# 5  /home/WIN.DTU.DK/matinnu/phd/projects/dyrehavn...

# %%
! qiime tools import \
    --type 'SampleData[PairedEndSequencesWithQuality]' \
    --input-path ../data/qiime2/manifest-selection.txt \
    --output-path ../data/qiime2/paired-end-demux.qza \
    --input-format PairedEndFastqManifestPhred33V2
# Out:
# Imported ../data/qiime2/manifest-selection.txt as PairedEndFastqManifestPhred33V2 to ../data/qiime2/paired-end-demux.qza

# %%
! qiime demux summarize \
  --i-data ../data/qiime2/paired-end-demux.qza \
  --o-visualization ../data/qiime2/paired-end-demux.qzv
# Out:
# Saved Visualization to: ../data/qiime2/paired-end-demux.qzv

# %%
from qiime2 import Artifact, Visualization
Visualization.load('../data/qiime2/paired-end-demux.qzv')
# Out:
# <visualization: Visualization uuid: e49eec88-6bb2-4e10-86e0-401241cc7fff>

# %%
! qiime vsearch join-pairs \
    --i-demultiplexed-seqs ../data/qiime2/paired-end-demux.qza \
    --p-threads 0 \
    --o-joined-sequences ../data/qiime2/joined-demux.qza \
    --verbose > ../data/qiime2/joined.log
# Out:
# /home/WIN.DTU.DK/matinnu/miniconda3/envs/qiime2-2021.2/lib/python3.6/site-packages/q2_vsearch/_join_pairs.py:93: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   demultiplexed_seqs.metadata.pathspec)))['phred-offset']
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     128220  Pairs
#     112472  Merged (87.7%)
#      15748  Not merged (12.3%)
#
# Pairs that failed merging due to various reasons:
#         59  too few kmers found on same diagonal
#         53  potential tandem repeat
#      11044  too many differences
#       4455  alignment score too low, or score drop to high
#        137  staggered read pairs
#
# Statistics of all reads:
#     273.54  Mean read length
#
# Statistics of merged reads:
#     418.12  Mean fragment length
#      11.12  Standard deviation of fragment length
#       1.94  Mean expected error in forward sequences
#       1.31  Mean expected error in reverse sequences
#       0.47  Mean expected error in merged sequences
#       1.52  Mean observed errors in merged region of forward sequences
#       0.98  Mean observed errors in merged region of reverse sequences
#       2.51  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     214505  Pairs
#     185959  Merged (86.7%)
#      28546  Not merged (13.3%)
#
# Pairs that failed merging due to various reasons:
#         35  too few kmers found on same diagonal
#         88  potential tandem repeat
#      19898  too many differences
#       8390  alignment score too low, or score drop to high
#        135  staggered read pairs
#
# Statistics of all reads:
#     273.63  Mean read length
#
# Statistics of merged reads:
#     418.34  Mean fragment length
#      11.04  Standard deviation of fragment length
#       2.00  Mean expected error in forward sequences
#       1.37  Mean expected error in reverse sequences
#       0.48  Mean expected error in merged sequences
#       1.57  Mean observed errors in merged region of forward sequences
#       1.04  Mean observed errors in merged region of reverse sequences
#       2.61  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#      82104  Pairs
#      71625  Merged (87.2%)
#      10479  Not merged (12.8%)
#
# Pairs that failed merging due to various reasons:
#          1  reads too short (after truncation)
#         14  too few kmers found on same diagonal
#         37  potential tandem repeat
#       7345  too many differences
#       2992  alignment score too low, or score drop to high
#          1  overlap too short
#         89  staggered read pairs
#
# Statistics of all reads:
#     273.60  Mean read length
#
# Statistics of merged reads:
#     418.09  Mean fragment length
#      11.22  Standard deviation of fragment length
#       2.00  Mean expected error in forward sequences
#       1.34  Mean expected error in reverse sequences
#       0.48  Mean expected error in merged sequences
#       1.57  Mean observed errors in merged region of forward sequences
#       1.00  Mean observed errors in merged region of reverse sequences
#       2.57  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     189744  Pairs
#     167610  Merged (88.3%)
#      22134  Not merged (11.7%)
#
# Pairs that failed merging due to various reasons:
#         42  too few kmers found on same diagonal
#         87  potential tandem repeat
#      15387  too many differences
#       6352  alignment score too low, or score drop to high
#        266  staggered read pairs
#
# Statistics of all reads:
#     273.62  Mean read length
#
# Statistics of merged reads:
#     418.36  Mean fragment length
#      10.94  Standard deviation of fragment length
#       1.96  Mean expected error in forward sequences
#       1.25  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.50  Mean observed errors in merged region of forward sequences
#       0.91  Mean observed errors in merged region of reverse sequences
#       2.41  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     146621  Pairs
#     129420  Merged (88.3%)
#      17201  Not merged (11.7%)
#
# Pairs that failed merging due to various reasons:
#         24  too few kmers found on same diagonal
#         71  potential tandem repeat
#      12068  too many differences
#       4887  alignment score too low, or score drop to high
#        151  staggered read pairs
#
# Statistics of all reads:
#     273.59  Mean read length
#
# Statistics of merged reads:
#     418.57  Mean fragment length
#      10.51  Standard deviation of fragment length
#       1.92  Mean expected error in forward sequences
#       1.26  Mean expected error in reverse sequences
#       0.47  Mean expected error in merged sequences
#       1.48  Mean observed errors in merged region of forward sequences
#       0.92  Mean observed errors in merged region of reverse sequences
#       2.40  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#      33961  Pairs
#      29457  Merged (86.7%)
#       4504  Not merged (13.3%)
#
# Pairs that failed merging due to various reasons:
#          7  too few kmers found on same diagonal
#          7  potential tandem repeat
#       3149  too many differences
#       1267  alignment score too low, or score drop to high
#         74  staggered read pairs
#
# Statistics of all reads:
#     273.43  Mean read length
#
# Statistics of merged reads:
#     414.85  Mean fragment length
#      11.30  Standard deviation of fragment length
#       1.97  Mean expected error in forward sequences
#       1.37  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.50  Mean observed errors in merged region of forward sequences
#       1.05  Mean observed errors in merged region of reverse sequences
#       2.54  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     249486  Pairs
#     220558  Merged (88.4%)
#      28928  Not merged (11.6%)
#
# Pairs that failed merging due to various reasons:
#         23  too few kmers found on same diagonal
#         95  potential tandem repeat
#      20483  too many differences
#       8136  alignment score too low, or score drop to high
#        191  staggered read pairs
#
# Statistics of all reads:
#     273.55  Mean read length
#
# Statistics of merged reads:
#     415.01  Mean fragment length
#      11.27  Standard deviation of fragment length
#       1.91  Mean expected error in forward sequences
#       1.28  Mean expected error in reverse sequences
#       0.43  Mean expected error in merged sequences
#       1.46  Mean observed errors in merged region of forward sequences
#       0.96  Mean observed errors in merged region of reverse sequences
#       2.42  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     168705  Pairs
#     146434  Merged (86.8%)
#      22271  Not merged (13.2%)
#
# Pairs that failed merging due to various reasons:
#         24  too few kmers found on same diagonal
#         40  potential tandem repeat
#      15754  too many differences
#       6272  alignment score too low, or score drop to high
#        181  staggered read pairs
#
# Statistics of all reads:
#     273.54  Mean read length
#
# Statistics of merged reads:
#     414.78  Mean fragment length
#      11.29  Standard deviation of fragment length
#       1.96  Mean expected error in forward sequences
#       1.38  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.51  Mean observed errors in merged region of forward sequences
#       1.05  Mean observed errors in merged region of reverse sequences
#       2.55  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     194028  Pairs
#     161961  Merged (83.5%)
#      32067  Not merged (16.5%)
#
# Pairs that failed merging due to various reasons:
#          1  reads too short (after truncation)
#         58  too few kmers found on same diagonal
#         51  potential tandem repeat
#      21387  too many differences
#      10202  alignment score too low, or score drop to high
#          1  overlap too short
#        367  staggered read pairs
#
# Statistics of all reads:
#     273.52  Mean read length
#
# Statistics of merged reads:
#     414.46  Mean fragment length
#      12.03  Standard deviation of fragment length
#       2.04  Mean expected error in forward sequences
#       1.44  Mean expected error in reverse sequences
#       0.51  Mean expected error in merged sequences
#       1.58  Mean observed errors in merged region of forward sequences
#       1.11  Mean observed errors in merged region of reverse sequences
#       2.68  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     211474  Pairs
#     179721  Merged (85.0%)
#      31753  Not merged (15.0%)
#
# Pairs that failed merging due to various reasons:
#         68  too few kmers found on same diagonal
#         84  potential tandem repeat
#      21937  too many differences
#       9420  alignment score too low, or score drop to high
#        244  staggered read pairs
#
# Statistics of all reads:
#     273.48  Mean read length
#
# Statistics of merged reads:
#     414.65  Mean fragment length
#      11.65  Standard deviation of fragment length
#       2.09  Mean expected error in forward sequences
#       1.46  Mean expected error in reverse sequences
#       0.49  Mean expected error in merged sequences
#       1.64  Mean observed errors in merged region of forward sequences
#       1.13  Mean observed errors in merged region of reverse sequences
#       2.77  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     110180  Pairs
#      97401  Merged (88.4%)
#      12779  Not merged (11.6%)
#
# Pairs that failed merging due to various reasons:
#         51  too few kmers found on same diagonal
#         50  potential tandem repeat
#       8645  too many differences
#       3822  alignment score too low, or score drop to high
#        211  staggered read pairs
#
# Statistics of all reads:
#     273.54  Mean read length
#
# Statistics of merged reads:
#     418.56  Mean fragment length
#      11.32  Standard deviation of fragment length
#       1.71  Mean expected error in forward sequences
#       1.39  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.26  Mean observed errors in merged region of forward sequences
#       1.02  Mean observed errors in merged region of reverse sequences
#       2.29  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#      57441  Pairs
#      50582  Merged (88.1%)
#       6859  Not merged (11.9%)
#
# Pairs that failed merging due to various reasons:
#         24  too few kmers found on same diagonal
#         31  potential tandem repeat
#       4467  too many differences
#       2035  alignment score too low, or score drop to high
#        302  staggered read pairs
#
# Statistics of all reads:
#     273.31  Mean read length
#
# Statistics of merged reads:
#     417.75  Mean fragment length
#      11.72  Standard deviation of fragment length
#       1.74  Mean expected error in forward sequences
#       1.30  Mean expected error in reverse sequences
#       0.44  Mean expected error in merged sequences
#       1.31  Mean observed errors in merged region of forward sequences
#       0.95  Mean observed errors in merged region of reverse sequences
#       2.26  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     470984  Pairs
#     411406  Merged (87.4%)
#      59578  Not merged (12.6%)
#
# Pairs that failed merging due to various reasons:
#        168  too few kmers found on same diagonal
#        193  potential tandem repeat
#      40361  too many differences
#      18400  alignment score too low, or score drop to high
#          1  overlap too short
#        455  staggered read pairs
#
# Statistics of all reads:
#     273.60  Mean read length
#
# Statistics of merged reads:
#     418.46  Mean fragment length
#      11.04  Standard deviation of fragment length
#       1.86  Mean expected error in forward sequences
#       1.34  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.42  Mean observed errors in merged region of forward sequences
#       0.99  Mean observed errors in merged region of reverse sequences
#       2.41  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     393440  Pairs
#     350874  Merged (89.2%)
#      42566  Not merged (10.8%)
#
# Pairs that failed merging due to various reasons:
#          1  reads too short (after truncation)
#        131  too few kmers found on same diagonal
#        174  potential tandem repeat
#      28405  too many differences
#      13308  alignment score too low, or score drop to high
#          3  overlap too short
#        544  staggered read pairs
#
# Statistics of all reads:
#     273.43  Mean read length
#
# Statistics of merged reads:
#     418.00  Mean fragment length
#      12.59  Standard deviation of fragment length
#       1.74  Mean expected error in forward sequences
#       1.24  Mean expected error in reverse sequences
#       0.43  Mean expected error in merged sequences
#       1.30  Mean observed errors in merged region of forward sequences
#       0.91  Mean observed errors in merged region of reverse sequences
#       2.21  Mean observed errors in merged region
# vsearch v2.7.0_linux_x86_64, 62.8GB RAM, 16 cores
# https://github.com/torognes/vsearch
#
# Merging reads 100%
#     268889  Pairs
#     235613  Merged (87.6%)
#      33276  Not merged (12.4%)
#
# Pairs that failed merging due to various reasons:
#        132  too few kmers found on same diagonal
#        115  potential tandem repeat
#      22607  too many differences
#      10104  alignment score too low, or score drop to high
#          1  overlap too short
#        317  staggered read pairs
#
# Statistics of all reads:
#     273.49  Mean read length
#
# Statistics of merged reads:
#     418.48  Mean fragment length
#      11.17  Standard deviation of fragment length
#       1.88  Mean expected error in forward sequences
#       1.36  Mean expected error in reverse sequences
#       0.46  Mean expected error in merged sequences
#       1.43  Mean observed errors in merged region of forward sequences
#       1.01  Mean observed errors in merged region of reverse sequences
#       2.45  Mean observed errors in merged region

# %%
! qiime demux summarize \
  --i-data ../data/qiime2/joined-demux.qza \
  --o-visualization ../data/qiime2/joined-demux.qzv
# Out:
# Saved Visualization to: ../data/qiime2/joined-demux.qzv

# %%
Visualization.load('../data/qiime2/joined-demux.qzv')
# Out:
# <visualization: Visualization uuid: fc90113e-08b4-430d-9ffe-8738920129ec>

# %%
! qiime quality-filter q-score \
    --i-demux ../data/qiime2/joined-demux.qza \
    --o-filtered-sequences ../data/qiime2/demux-filtered.qza \
    --o-filter-stats ../data/qiime2/demux-filter-stats.qza
# Out:
# Saved SampleData[JoinedSequencesWithQuality] to: ../data/qiime2/demux-filtered.qza
# Saved QualityFilterStats to: ../data/qiime2/demux-filter-stats.qza

# %%
! qiime deblur denoise-16S \
    --i-demultiplexed-seqs ../data/qiime2/demux-filtered.qza \
    --p-trim-length 400 \
    --o-representative-sequences ../data/qiime2/rep-seqs-deblur.qza \
    --o-table ../data/qiime2/table-deblur.qza \
    --p-sample-stats \
    --p-jobs-to-start 8 \
    --o-stats ../data/qiime2/deblur-stats.qza \
    --verbose
# Out:
# Saved FeatureTable[Frequency] to: ../data/qiime2/table-deblur.qza
# Saved FeatureData[Sequence] to: ../data/qiime2/rep-seqs-deblur.qza
# Saved DeblurStats to: ../data/qiime2/deblur-stats.qza

# %%
! qiime metadata tabulate \
  --m-input-file ../data/qiime2/demux-filter-stats.qza \
  --o-visualization ../data/qiime2/demux-filter-stats.qzv

! qiime deblur visualize-stats \
  --i-deblur-stats ../data/qiime2/deblur-stats.qza \
  --o-visualization ../data/qiime2/deblur-stats.qzv
# Out:
# Saved Visualization to: ../data/qiime2/demux-filter-stats.qzv
# Saved Visualization to: ../data/qiime2/deblur-stats.qzv

# %%
Visualization.load('../data/qiime2/demux-filter-stats.qzv')
# Out:
# <visualization: Visualization uuid: 063369c0-fe41-4a9f-8eea-17f0ea386b47>

# %%
Visualization.load('../data/qiime2/deblur-stats.qzv')
# Out:
# <visualization: Visualization uuid: 2750eddb-7e2d-4dd8-bff3-10a14ccb16ad>

# %%
df1 = pd.read_csv('../data/metadata/Psoil-1_barcode.tsv', sep='\t')
df2 = pd.read_csv('../data/metadata/Psoil-2_barcode.tsv', sep='\t')
df3 = pd.read_csv('../data/metadata/Psoil-3_barcode.tsv', sep='\t')
frames = [df1, df2, df3]
df_all = pd.concat(frames)
df_all = df_all[df_all['#SampleID'].isin([i for i in df_all['#SampleID'] if i.startswith(('P5', 'P8', 'P9'))])].reset_index(drop=True)
for num, i in enumerate(df_all['#SampleID']):
    df_all.loc[num, '#SampleID'] = i.replace('_', '-')
df_all.to_csv('../data/metadata/metadata-selection.tsv', sep='\t', index=False)
df_all
# Out:
#    #SampleID BarcodeSequence Sample
# 0    P5-rep1        GCTTCTGA     P5
# 1    P5-rep2        GGCAAGAT     P5
# 2    P5-rep3        GTGCTTTC     P5
# 3    P5-rep4        ACACACTG     P5
# 4    P5-rep5        CGATTCTG     P5
# 5    P8-rep1        GCAGAGTT     P8
# 6    P8-rep2        CGTCCTAT     P8
# 7    P8-rep3        GCTTGGTT     P8
# 8    P8-rep4        ACAGGCTT     P8
# 9    P8-rep5        TGACGCTT     P8
# 10   P9-rep1        TTTTAATC     P9
# 11   P9-rep2        ATAATTAG     P9
# 12   P9-rep3        ACCAAATT     P9
# 13   P9-rep4        CTTATCAA     P9
# 14   P9-rep5        TGATCATT     P9

# %%
! qiime feature-table summarize \
        --i-table ../data/qiime2/table-deblur.qza \
        --o-visualization ../data/qiime2/table-deblur.qzv \
        --m-sample-metadata-file ../data/metadata/metadata-selection.tsv

! qiime feature-table tabulate-seqs \
        --i-data ../data/qiime2/rep-seqs-deblur.qza \
        --o-visualization ../data/qiime2/rep-seqs-deblur.qzv
# Out:
# Saved Visualization to: ../data/qiime2/table-deblur.qzv
# Saved Visualization to: ../data/qiime2/rep-seqs-deblur.qzv

# %%
Visualization.load('../data/qiime2/table-deblur.qzv')
# Out:
# <visualization: Visualization uuid: 0b373b64-aae6-41c4-a086-22ad3d43911f>

# %%
Visualization.load('../data/qiime2/rep-seqs-deblur.qzv')
# Out:
# <visualization: Visualization uuid: 3bd393c6-526b-44cb-a321-dcd5ee481d48>
